# %% [markdown]
# ### Group Members :
# - นายกลวัชร เสถียรเสรีสุข  6210450016
# - นายเกียรติกุล ทองอุดม    6210450032
# - นายชาญวิทย์ สายสิญจน์  6210450521
# - น.ส.ณัฎฐกานต์ อรสุนทร   6210451144
# - น.ส.ธันวพร ธรรมเจริญพงศ์ 6210451225

# %%
import pandas as pd
import datetime as dt
import seaborn as sns

# %%
df = pd.read_csv('movies.csv')
# Out:
# /Users/nattakarn/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df
# Out:
#       imdb_title_id                           title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                  Den sorte drøm
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85852     tt9911774       Padmavyuhathile Abhimanyu
# 85853     tt9914286               Sokagin Çocuklari
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year date_published  \
# 0                          Miss Jerry  1894     1894-10-09
# 1         The Story of the Kelly Gang  1906     1906-12-26
# 2                      Den sorte drøm  1911     1911-08-19
# 3                           Cleopatra  1912     1912-11-13
# ...

# %% [markdown]
# ## รายละเอียดข้อมูล
# #### แหล่งที่มาของข้อมูล

# %% [markdown]
# - https://www.kaggle.com/stefanoleone992/imdb-extensive-dataset

# %% [markdown]
# #### เก็บรวบรวมโดย

# %% [markdown]
# - Stefano Leone

# %% [markdown]
# #### รายละเอียดคอลัมป์

# %% [markdown]
# 1. imdb_title_id - รหัสของหนังแต่ละเรื่อง
# 2. title - ชื่อเรื่อง
# 3. original_title - ชื่อเรื่องจากต้นฉบับ
# 4. year - ปีที่กำหนดฉาย
# 5. date_published - วันที่กำหนดฉาย
# 6. genre - ประเภทของหนัง
# 7. duration - ระยะเวลาของหนัง(ต้นเรื่อง - จบเรื่อง) `หน่วย minutes`
# 8. country - ประเทศที่ผลิต
# 9. language - ภาษาของหนัง
# 10. director - ผู้กำกับการแสดง
# 11. writer - ผู้เขียน
# 12. production_company - บริษัทที่สร้างหนัง
# 13. actor - นักแสดง
# 14. description - คำอธิบายหนัง, เกริ่นเนื้อเรื่องย่อ
# 15. avg_vote - ค่าเฉลี่ยคะแนนโหวต
# 16. votes - จำนวนที่โหวตทั้งหมด
# 17. budget - งบประมาณการสร้าง
# 18. usa_gross_income - รายได้รวมจากการฉายหนัง
# 19. worlwide_gross_income - รายได้รวมทั่วโลกจากการฉายหนัง
# 20. metascore - คะแนนจากการวิจารณ์ของสื่อต่างๆ
# 21. reviews_from_users - การรีวิวจากผู้ชม
# 22. reviews_from_critics - การรีวิลจากนักวิจารณ์

# %% [markdown]
# #### ตรวจสอบข้อมูลในตาราง

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85855 entries, 0 to 85854
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_title_id          85855 non-null  object
#  1   title                  85855 non-null  object
#  2   original_title         85855 non-null  object
#  3   year                   85855 non-null  object
#  4   date_published         85855 non-null  object
#  5   genre                  85855 non-null  object
#  6   duration               85855 non-null  int64
#  7   country                85791 non-null  object
#  8   language               85022 non-null  object
#  9   director               85768 non-null  object
#  10  writer                 84283 non-null  object
#  11  production_company     81400 non-null  object
#  12  actors                 85786 non-null  object
#  13  description            83740 non-null  object
# ...

# %% [markdown]
# #### จำนวนแถวกับคอลัมป์ของตาราง

# %%
df.shape
# Out:
# (85855, 22)

# %% [markdown]
# #### จำนวนข้อมูลในแต่ละคอลัมป์ที่เป็น Nan

# %%
df.isna().sum()
# Out:
# imdb_title_id                0
# title                        0
# original_title               0
# year                         0
# date_published               0
# genre                        0
# duration                     0
# country                     64
# language                   833
# director                    87
# writer                    1572
# production_company        4455
# actors                      69
# description               2115
# avg_vote                     0
# votes                        0
# budget                   62145
# usa_gross_income         70529
# worlwide_gross_income    54839
# metascore                72550
# reviews_from_users        7597
# reviews_from_critics     11797
# dtype: int64

# %% [markdown]
# #### ชื่อหนังและปีที่มีจำนวนการโหวตมากที่สุด

# %%
df.loc[df.votes == df.votes.max(),['original_title','year','votes']]
# Out:
#                  original_title  year    votes
# 28453  The Shawshank Redemption  1994  2278845

# %% [markdown]
# #### จำนวนหนังทั้งหมด แยกตามปีที่ฉาย

# %%
df.groupby(df.year).size()
# Out:
# year
# 1894                1
# 1906                1
# 1911                5
# 1912                5
# 1913               13
#                  ...
# 2017             3223
# 2018             3182
# 2019             2168
# 2020              401
# TV Movie 2019       1
# Length: 168, dtype: int64

# %% [markdown]
# #### จะเห็นว่ามีปีที่ฉายแตกต่างจากปีอื่น นั่นคือ `TV Movie 2019`

# %%
df.loc[df.year == 'TV Movie 2019']
# Out:
#       imdb_title_id          title original_title           year  \
# 83917     tt8206668  Bad Education  Bad Education  TV Movie 2019
#
#       date_published                     genre  duration country language  \
# 83917  TV Movie 2019  Biography, Comedy, Crime       108     USA  English
#
#           director  ...                                             actors  \
# 83917  Cory Finley  ...  Hugh Jackman, Ray Romano, Welker White, Alliso...
#
#                                              description avg_vote  votes  \
# 83917  The beloved superintendent of New York's Rosly...      7.1  23973
#
#        budget  usa_gross_income worlwide_gross_income metascore  \
# 83917     NaN               NaN                   NaN      79.0
#
#       reviews_from_users  reviews_from_critics
# 83917              135.0                  98.0
#
# [1 rows x 22 columns]

# %% [markdown]
# #### ทำการเปลี่ยนข้อมูลข้างในเป็นปี 2019

# %%
df.loc[df.year == 'TV Movie 2019','year'] = '2019'

# %%
df.loc[df.index == 83917]
# Out:
#       imdb_title_id          title original_title  year date_published  \
# 83917     tt8206668  Bad Education  Bad Education  2019  TV Movie 2019
#
#                           genre  duration country language     director  ...  \
# 83917  Biography, Comedy, Crime       108     USA  English  Cory Finley  ...
#
#                                                   actors  \
# 83917  Hugh Jackman, Ray Romano, Welker White, Alliso...
#
#                                              description avg_vote  votes  \
# 83917  The beloved superintendent of New York's Rosly...      7.1  23973
#
#        budget  usa_gross_income worlwide_gross_income metascore  \
# 83917     NaN               NaN                   NaN      79.0
#
#       reviews_from_users  reviews_from_critics
# 83917              135.0                  98.0
#
# [1 rows x 22 columns]

# %% [markdown]
# #### จำนวนหนังทั้งหมด แยกตามปีที่ฉาย อีกครั้ง

# %%
df.groupby(df.year).size()
# Out:
# year
# 1894       1
# 1906       1
# 1911       5
# 1912       5
# 1913      13
#         ...
# 2016    2992
# 2017    3223
# 2018    3182
# 2019    2169
# 2020     401
# Length: 167, dtype: int64

# %% [markdown]
# #### แผนภาพการกระจายตัวของปีที่ฉายหนัง

# %%
sns.distplot(df.year)
# Out:
# /Users/nattakarn/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='year', ylabel='Density'>

# %% [markdown]
# #### หนังที่มี ผู้กำกับ (director) และ ผู้เขียน (writer) เหมือนกัน

# %%
df.loc[df.director == df.writer]
# Out:
#       imdb_title_id                        title               original_title  \
# 0         tt0000009                   Miss Jerry                   Miss Jerry
# 1         tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 15        tt0003131       Maudite soit la guerre       Maudite soit la guerre
# 26        tt0003883            L'enfant de Paris            L'enfant de Paris
# 29        tt0004026                    Der Golem                    Der Golem
# ...             ...                          ...                          ...
# 85840     tt9899850                    Ashoftegi                    Ashoftegi
# 85841     tt9899880                     Columbus                     Columbus
# 85844     tt9903716                       Jessie                       Jessie
# 85845     tt9904250     La reina de los lagartos     La reina de los lagartos
# 85848     tt9905462                    Pengalila                    Pengalila
#
# ...

# %% [markdown]
# # แยกหนังตามประเภทของหนัง

# %%
df.groupby('genre').size()
# Out:
# genre
# Action                          715
# Action, Adventure               200
# Action, Adventure, Biography     31
# Action, Adventure, Comedy       606
# Action, Adventure, Crime        229
#                                ...
# Western, Comedy                   6
# Western, Comedy, Drama            1
# Western, Drama                    3
# Western, Family                   1
# Western, Horror                   1
# Length: 1257, dtype: int64

# %%
new_genre = pd.DataFrame(df.genre.str.split(',',expand=True))

# %%
new_genre
# Out:
#                0         1         2
# 0        Romance      None      None
# 1      Biography     Crime     Drama
# 2          Drama      None      None
# 3          Drama   History      None
# 4      Adventure     Drama   Fantasy
# ...          ...       ...       ...
# 85850     Comedy      None      None
# 85851     Comedy     Drama      None
# 85852      Drama      None      None
# 85853      Drama    Family      None
# 85854      Drama      None      None
#
# [85855 rows x 3 columns]

# %%
new_genre.columns = ['a','b','c']

# %%
a = new_genre.a
b = new_genre.b
c = new_genre.c
frame = [a,b,c]


genre_ = pd.concat(frame)

# %%
genre_.value_counts()
# Out:
# Drama          25386
# Comedy         24297
#  Drama         21724
#  Romance       13361
# Action         12182
#  Thriller      10013
# Crime           5557
#  Crime          5510
# Horror          5113
#  Comedy         5071
#  Mystery        4632
#  Horror         4444
#  Adventure      3991
# Adventure       3599
#  Family         3324
#  Fantasy        3310
#  Sci-Fi         3191
#  History        2216
#  War            2135
# Animation       2108
# Biography       2067
#  Musical        1717
#  Music          1612
# Thriller        1375
#  Sport          1048
#  Western         966
# Romance          767
#  Action          766
# Family           638
#  Film-Noir       634
# Western          617
# Mystery          593
# Fantasy          502
# Sci-Fi           417
# Musical          324
#  Biography       310
# War              107
# History           80
# Music             77
#  Animation        33
# Film-Noir         29
# Sport             16
#  Reality-TV        3
# ...

# %%
genre_.unique()
# Out:
# array(['Romance', 'Biography', 'Drama', 'Adventure', 'History', 'Crime',
#        'Western', 'Fantasy', 'Comedy', 'Horror', 'Family', 'Action',
#        'Mystery', 'Sci-Fi', 'Animation', 'Thriller', 'Musical', 'Music',
#        'War', 'Film-Noir', 'Sport', 'Adult', 'Documentary', None,
#        ' Crime', ' History', ' Drama', ' War', ' Fantasy', ' Mystery',
#        ' Family', ' Adventure', ' Romance', ' Comedy', ' Western',
#        ' Horror', ' Thriller', ' Sport', ' Sci-Fi', ' Action', ' Music',
#        ' Musical', ' Biography', ' Film-Noir', ' Animation',
#        ' Reality-TV', ' News'], dtype=object)

# %%
final_genre = pd.DataFrame(genre_.unique())

# %%
final_genre
# Out:
#               0
# 0       Romance
# 1     Biography
# 2         Drama
# 3     Adventure
# 4       History
# 5         Crime
# 6       Western
# 7       Fantasy
# 8        Comedy
# 9        Horror
# 10       Family
# 11       Action
# 12      Mystery
# 13       Sci-Fi
# 14    Animation
# 15     Thriller
# 16      Musical
# 17        Music
# 18          War
# 19    Film-Noir
# 20        Sport
# 21        Adult
# 22  Documentary
# 23         None
# 24        Crime
# 25      History
# 26        Drama
# 27          War
# 28      Fantasy
# 29      Mystery
# 30       Family
# 31    Adventure
# 32      Romance
# 33       Comedy
# 34      Western
# 35       Horror
# 36     Thriller
# 37        Sport
# 38       Sci-Fi
# 39       Action
# 40        Music
# 41      Musical
# 42    Biography
# 43    Film-Noir
# 44    Animation
# 45   Reality-TV
# 46         News

# %%
df.loc[df.genre.str.contains('Romance'),'title']
# Out:
# 0                                           Miss Jerry
# 6                                       Madame DuBarry
# 37                                       The Squaw Man
# 44                               The Wrath of the Gods
# 49                                           The Cheat
#                              ...
# 85811    Falling Inn Love - Ristrutturazione con amore
# 85822                                    Nalpathiyonnu
# 85823                                      Subharathri
# 85828                                 Munthiri Monchan
# 85829                                   Season of Love
# Name: title, Length: 14128, dtype: object
